# %%
import pandas as pd
import numpy as np
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import lib.points as gpxpt
import lib.directions as dir
import lib.map as gmap
import lib.time as tm

# %matplotlib inline
DATA_FOLDER = '../data/'

# %%
gpxpt.writeSplitRoutePoints(os.path.join(DATA_FOLDER,
                                        'route.gpx'), os.path.join(DATA_FOLDER,
                                        'pts-100.csv'), 100)

# %%
gpxpt.writeSplitRoutePoints(os.path.join(DATA_FOLDER,
                                        'route.gpx'), os.path.join(DATA_FOLDER,
                                        'pts-200.csv'), 200)

# %%
gpxpt.writeSplitRoutePoints(os.path.join(DATA_FOLDER,
                                        'route.gpx'), os.path.join(DATA_FOLDER,
                                        'pts-400.csv'), 400)

# %%
gpxpt.writeSplitRoutePoints(os.path.join(DATA_FOLDER,
                                        'route.gpx'), os.path.join(DATA_FOLDER,
                                        'pts-500.csv'), 500)

# %%
points100 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'pts-100.csv'))
points200 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'pts-200.csv'))
points400 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'pts-400.csv'))
points500 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'pts-500.csv'))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'pts-100.csv'), os.path.join(DATA_FOLDER,
                                        'speeds-100.csv'))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'pts-200.csv'), os.path.join(DATA_FOLDER,
                                        'speeds-200.csv'))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'pts-400.csv'), os.path.join(DATA_FOLDER,
                                        'speeds-400.csv'))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'pts-500.csv'), os.path.join(DATA_FOLDER,
                                        'speeds-500.csv'))

# %%
speeds100 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'speeds-100.csv'))
speeds200 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'speeds-200.csv'))
speeds400 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'speeds-400.csv'))
speeds500 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'speeds-500.csv'))

# %%
for i in (speeds100, speeds200, speeds400, speeds500):
    i['Speed'] = pd.Series(np.where(i['Duration'] < 0.000001, 
                                     i['Duration'], 
                                     (i['Distance']/1000)/(i['Duration']/3600)), index=i.index)
    i["Milestones"] = pd.Series(i.Distance.cumsum(), index=i.index)

# %%
for i in (points100, points200, points400, points500):
    gmap.plot([(pt["Lat"], pt["Lng"]) for idx, pt in i.iterrows()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-ead23b769f5a> in <module>()
# ----> 1 for i in (points100, points200, points400, points500):
#       2     gmap.plot([(pt["Lat"], pt["Lng"]) for idx, pt in i.iterrows()])
#
# NameError: name 'points100' is not defined

# %%
for i in (speeds100, speeds200, speeds400, speeds500):
    plt = i.plot(x='Milestones', y='Speed', kind='line', figsize=(15,7))
    plt.set_xlabel("Milestones (m)")
    plt.set_ylabel("Speed (km / hr)")

# %%
gpxpt.writeSplitRoutePoints(os.path.join(DATA_FOLDER,
                                        'MWKGAR.gpx'), os.path.join(DATA_FOLDER,
                                        'mwkgarpts-100.csv'), 100)

# %%
gpxpt.writeSplitRoutePoints(os.path.join(DATA_FOLDER,
                                        'MWKGAR.gpx'), os.path.join(DATA_FOLDER,
                                        'mwkgarpts-200.csv'), 200)

# %%
gpxpt.writeSplitRoutePoints(os.path.join(DATA_FOLDER,
                                        'MWKGAR.gpx'), os.path.join(DATA_FOLDER,
                                        'mwkgarpts-400.csv'), 400)

# %%
gpxpt.writeSplitRoutePoints(os.path.join(DATA_FOLDER,
                                        'MWKGAR.gpx'), os.path.join(DATA_FOLDER,
                                        'mwkgarpts-500.csv'), 500)

# %%
mwkgarpoints100 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-100.csv'))
mwkgarpoints200 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-200.csv'))
mwkgarpoints400 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-400.csv'))
mwkgarpoints500 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-500.csv'))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-100.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/9/mwkgarspeeds-100.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 09:00:00", "America/Chicago"))

# %%
tm.getTimeFromEpoch("2017-5-24 09:00:00", "America/Chicago")
# Out:
# 1495634400.0

# %%
tm.getTimeFromEpoch("2017-5-31 18:00:00", "America/Chicago")
# Out:
# 1496271600.0

# %%
dir.getDistAndDuration(lat1 = "43.03443336",lng1 = "-87.92372477",lat2 = "43.03354292",lng2 = "-87.92363682", depTime = tm.getTimeFromEpoch("2017-5-31 18:00:00", "America/Chicago"))
# Out:
# [98, 5]

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-200.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/9/mwkgarspeeds-200.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 09:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-400.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/9/mwkgarspeeds-400.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 09:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-500.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/9/mwkgarspeeds-500.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 09:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-100.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/12/mwkgarspeeds-100.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 12:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-200.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/12/mwkgarspeeds-200.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 12:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-400.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/12/mwkgarspeeds-400.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 12:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-500.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/12/mwkgarspeeds-500.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 12:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-100.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/18/mwkgarspeeds-100.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 18:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-200.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/18/mwkgarspeeds-200.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 18:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-400.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/18/mwkgarspeeds-400.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 18:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-500.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/18/mwkgarspeeds-500.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 18:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-100.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/3/mwkgarspeeds-100.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 03:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-200.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/3/mwkgarspeeds-200.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 03:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-400.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/3/mwkgarspeeds-400.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 03:00:00", "America/Chicago"))

# %%
dir.writeDistAndDuration(os.path.join(DATA_FOLDER,
                                        'mwkgarpts-500.csv'), os.path.join(DATA_FOLDER,
                                        'mwkgar/3/mwkgarspeeds-500.csv'), depTime=tm.getTimeFromEpoch("2017-5-24 03:00:00", "America/Chicago"))

# %% [markdown]
# ## Milwaukee - Gary : 100 m intervals

# %%
mwkGar100 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgar/3/mwkgarspeeds-100.csv'))
mwkGar100['Speed-3'] = pd.Series(np.where(mwkGar100['Duration'] < 0.000001, 
                                     mwkGar100['Duration'], 
                                     (mwkGar100['Distance']/1000)/(mwkGar100['Duration']/3600)), index=mwkGar100.index)
mwkGar100["Milestones"] = pd.Series(mwkGar100.Distance.cumsum(), index=mwkGar100.index)

# %%
for i in (9, 12, 18):
    df = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgar/' + str(i) + '/mwkgarspeeds-100.csv'))
    mwkGar100['Speed-' + str(i)] = pd.Series(np.where(df['Duration'] < 0.000001, 
                                     df['Duration'], 
                                     df['Distance']/df['Duration']), index=df.index)

# %%
plt = mwkGar100.plot(x='Milestones', y=["Speed-3", "Speed-9", "Speed-12", "Speed-18"], kind='line', figsize=(15,7))
plt.set_xlabel("Milestones (m)")
plt.set_ylabel("Speed (km / hr)")

# %% [markdown]
# ## Milwaukee - Gary : 200 m intervals

# %%
mwkGar200 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgar/3/mwkgarspeeds-200.csv'))
mwkGar200['Speed-3'] = pd.Series(np.where(mwkGar200['Duration'] < 0.000001, 
                                     mwkGar200['Duration'], 
                                     (mwkGar200['Distance']/1000)/(mwkGar200['Duration']/3600)), index=mwkGar200.index)
mwkGar200["Milestones"] = pd.Series(mwkGar200.Distance.cumsum(), index=mwkGar200.index)

# %%
for i in (9, 12, 18):
    df = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgar/' + str(i) + '/mwkgarspeeds-200.csv'))
    mwkGar200['Speed-' + str(i)] = pd.Series(np.where(df['Duration'] < 0.000001, 
                                     df['Duration'], 
                                     df['Distance']/df['Duration']), index=df.index)

# %%
plt = mwkGar200.plot(x='Milestones', y=["Speed-3", "Speed-9", "Speed-12", "Speed-18"], kind='line', figsize=(15,7))
plt.set_xlabel("Milestones (m)")
plt.set_ylabel("Speed (km / hr)")

# %% [markdown]
# ## Milwaukee - Gary : 400 m intervals

# %%
mwkGar400 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgar/3/mwkgarspeeds-400.csv'))
mwkGar400['Speed-3'] = pd.Series(np.where(mwkGar400['Duration'] < 0.000001, 
                                     mwkGar400['Duration'], 
                                     (mwkGar400['Distance']/1000)/(mwkGar400['Duration']/3600)), index=mwkGar400.index)
mwkGar400["Milestones"] = pd.Series(mwkGar400.Distance.cumsum(), index=mwkGar400.index)

# %%
for i in (9, 12, 18):
    df = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgar/' + str(i) + '/mwkgarspeeds-400.csv'))
    mwkGar400['Speed-' + str(i)] = pd.Series(np.where(df['Duration'] < 0.000001, 
                                     df['Duration'], 
                                     df['Distance']/df['Duration']), index=df.index)

# %%
plt = mwkGar400.plot(x='Milestones', y=["Speed-3", "Speed-9", "Speed-12", "Speed-18"], kind='line', figsize=(15,7))
plt.set_xlabel("Milestones (m)")
plt.set_ylabel("Speed (km / hr)")

# %% [markdown]
# ## Milwaukee - Gary : 500 m intervals

# %%
mwkGar500 = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgar/3/mwkgarspeeds-500.csv'))
mwkGar500['Speed-3'] = pd.Series(np.where(mwkGar500['Duration'] < 0.000001, 
                                     mwkGar500['Duration'], 
                                     (mwkGar500['Distance']/1000)/(mwkGar500['Duration']/3600)), index=mwkGar500.index)
mwkGar500["Milestones"] = pd.Series(mwkGar500.Distance.cumsum(), index=mwkGar500.index)

# %%
for i in (9, 12, 18):
    df = pd.read_csv(os.path.join(DATA_FOLDER,
                                        'mwkgar/' + str(i) + '/mwkgarspeeds-500.csv'))
    mwkGar500['Speed-' + str(i)] = pd.Series(np.where(df['Duration'] < 0.000001, 
                                     df['Duration'], 
                                     df['Distance']/df['Duration']), index=df.index)

# %%
plt = mwkGar500.plot(x='Milestones', y=["Speed-3", "Speed-9", "Speed-12", "Speed-18"], kind='line', figsize=(15,7))
plt.set_xlabel("Milestones (m)")
plt.set_ylabel("Speed (km / hr)")
